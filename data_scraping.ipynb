# %%
## Importing libraries

import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.cloud import bigquery
import random

# %%
# %reload_ext google.cloud.bigquery
client = bigquery.Client(project="neural-ds-fe73")
# Out:
# /Users/navunni/opt/anaconda3/envs/neuralds25/lib/python3.11/site-packages/google/cloud/bigquery/__init__.py:237: FutureWarning: %load_ext google.cloud.bigquery is deprecated. Install bigquery-magics package and use `%load_ext bigquery_magics`, instead.
#   warnings.warn(
# /Users/navunni/opt/anaconda3/envs/neuralds25/lib/python3.11/site-packages/google/auth/_default.py:108: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
# %%bigquery motor_cortex --project neural-ds-fe73 --use_rest_api
# select *
# from `neural-ds-fe73.lab4_population_coding.motor_cortex`
# Out:
# /Users/navunni/opt/anaconda3/envs/neuralds25/lib/python3.11/site-packages/google/cloud/bigquery/job/query.py:2159: UserWarning: A progress bar was requested, but there was an error loading the tqdm library. Please install tqdm to use the progress bar functionality.
#   query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
# /Users/navunni/opt/anaconda3/envs/neuralds25/lib/python3.11/site-packages/google/cloud/bigquery/table.py:2689: UserWarning: A progress bar was requested, but there was an error loading the tqdm library. Please install tqdm to use the progress bar functionality.
#   record_batch = self.to_arrow(

# %%
type(motor_cortex)
motor_cortex.shape
# Out:
# (45188, 8)

# %%
motor_cortex
# Out:
#        trial_id  cell_id brain_area       window  spike_count  direction  \
# 0             0        0        PMd  instruction          0.0          3
# 1             0        0        PMd           go          8.0          3
# 2             0        1        PMd  instruction          9.0          3
# 3             0        1        PMd           go         23.0          3
# 4             0        2        PMd  instruction          3.0          3
# ...         ...      ...        ...          ...          ...        ...
# 45183       157      140         MI           go         16.0          8
# 45184       157      141         MI  instruction          0.0          8
# 45185       157      141         MI           go          2.0          8
# 45186       157      142         MI  instruction          4.0          8
# 45187       157      142         MI           go          7.0          8
#
#        instruction_time      go_time
# 0             14.852567    16.308333
# ...

# %%
output = "./raw_data/motor_cortex.csv"
motor_cortex.to_csv(output, index=False)
